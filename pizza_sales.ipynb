# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pizza_sales = pd.read_csv('pizza_sales (1).csv')

# %%
pizza_sales.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0         1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1         2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2         3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3         4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4         5         2     mexicana_m         1  01-01-2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
pizza_sales.duplicated().sum()
# Out:
# 0

# %%
pizza_sales.nunique().sum()
# Out:
# 86959

# %%
pizza_sales.shape
# Out:
# (48620, 12)

# %%
pizza_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
pizza_sales.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
pizza_sales.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
pizza_sales.total_price.sum() #Total Revenue
# Out:
# 817860.05

# %%
pizza_sales.quantity.sum() #Total pizza sold
# Out:
# 49574

# %%
 pizza_sales.groupby('pizza_category')['total_price'].sum().sort_values()
# Total Pizza Sold by Pizza Category
# Out:
# pizza_category
# Veggie     193690.45
# Chicken    195919.50
# Supreme    208197.00
# Classic    220053.10
# Name: total_price, dtype: float64

# %%
pizza_sales.order_id.nunique() #distinct order_id as Total order
# Out:
# 21350

# %%
pizza_sales.total_price.sum()//pizza_sales.order_id.nunique() # Average order value
# Out:
# 38.0

# %%
pizza_sales.quantity.sum()//pizza_sales.order_id.nunique() #Average pizza per order
# Out:
# 2

# %%
import datetime as dt # to change the data type from object to datetime

# %%
pizza_sales.tail() # the last five rows
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# 48615       16.75        16.75          M        Chicken
# 48616       17.95        17.95          L         Veggie
# 48617       12.00        12.00          S        Classic
# 48618       20.25        20.25          L         Veggie
# 48619       12.75        12.75          S        Chicken
#
#                                        pizza_ingredients  \
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# ...

# %%
pizza_sales['order_date']= pizza_sales['order_date'].apply(lambda x:dt.datetime.strptime(x, '%d-%m-%Y')) # to convert object to datetime

# %%
pizza_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 4.5+ MB

# %%
pizza_sales.order_date.dt.day_name() #vcreate a date of the week column
# Out:
# 0        Thursday
# 1        Thursday
# 2        Thursday
# 3        Thursday
# 4        Thursday
#            ...
# 48615    Thursday
# 48616    Thursday
# 48617    Thursday
# 48618    Thursday
# 48619    Thursday
# Name: order_date, Length: 48620, dtype: object

# %%
pizza_sales['order_time']= pd.to_datetime(pizza_sales['order_time']) # to convert from object to datetime data type
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7192\54918861.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pizza_sales['order_time']= pd.to_datetime(pizza_sales['order_time']) # to convert from object to datetime data type

# %%
pizza_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  datetime64[ns]
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(5)
# memory usage: 4.5+ MB

# %%
pizza_sales['order_time'].dt.hour.value_counts()#to extract hour
# Out:
# order_time
# 12    6543
# 13    6203
# 18    5359
# 17    5143
# 19    4350
# 16    4185
# 14    3521
# 20    3487
# 15    3170
# 11    2672
# 21    2528
# 22    1370
# 23      68
# 10      17
# 9        4
# Name: count, dtype: int64

# %%
pizza_sales['hour']=pizza_sales['order_time'].dt.hour

# %%
pizza_sales
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date  \
# 0             1         1     hawaiian_m         1 2015-01-01
# 1             2         2  classic_dlx_m         1 2015-01-01
# 2             3         2  five_cheese_l         1 2015-01-01
# 3             4         2    ital_supr_l         1 2015-01-01
# 4             5         2     mexicana_m         1 2015-01-01
# ...         ...       ...            ...       ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616     48617     21348  four_cheese_l         1 2015-12-31
# 48617     48618     21348   napolitana_s         1 2015-12-31
# 48618     48619     21349     mexicana_l         1 2015-12-31
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31
#
#                order_time  unit_price  total_price pizza_size pizza_category  \
# 0     2024-10-28 11:38:36       13.25        13.25          M        Classic
# ...

# %%
pizza_sales.groupby('hour')['order_id'].nunique().sort_values()
# Out:
# hour
# 9        1
# 10       8
# 23      28
# 22     663
# 21    1198
# 11    1231
# 15    1468
# 14    1472
# 20    1642
# 16    1920
# 19    2009
# 17    2336
# 18    2399
# 13    2455
# 12    2520
# Name: order_id, dtype: int64

# %%
pizza_sales.groupby('pizza_name')['quantity'].sum().sort_values().head(5)
# Out:
# pizza_name
# The Brie Carre Pizza         490
# The Mediterranean Pizza      934
# The Calabrese Pizza          937
# The Spinach Supreme Pizza    950
# The Soppressata Pizza        961
# Name: quantity, dtype: int64

# %%
pizza_sales
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date  \
# 0             1         1     hawaiian_m         1 2015-01-01
# 1             2         2  classic_dlx_m         1 2015-01-01
# 2             3         2  five_cheese_l         1 2015-01-01
# 3             4         2    ital_supr_l         1 2015-01-01
# 4             5         2     mexicana_m         1 2015-01-01
# ...         ...       ...            ...       ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616     48617     21348  four_cheese_l         1 2015-12-31
# 48617     48618     21348   napolitana_s         1 2015-12-31
# 48618     48619     21349     mexicana_l         1 2015-12-31
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31
#
#                order_time  unit_price  total_price pizza_size pizza_category  \
# 0     2024-10-28 11:38:36       13.25        13.25          M        Classic
# ...

# %%
pizza_sales.groupby('pizza_name')['quantity'].sum().sort_values(ascending=False).head(5)
# Out:
# pizza_name
# The Classic Deluxe Pizza      2453
# The Barbecue Chicken Pizza    2432
# The Hawaiian Pizza            2422
# The Pepperoni Pizza           2418
# The Thai Chicken Pizza        2371
# Name: quantity, dtype: int64

# %%
pizza_sales.groupby('pizza_size')['quantity'].sum()
# Out:
# pizza_size
# L      18956
# M      15635
# S      14403
# XL       552
# XXL       28
# Name: quantity, dtype: int64

# %%
pizza_sales
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date  \
# 0             1         1     hawaiian_m         1 2015-01-01
# 1             2         2  classic_dlx_m         1 2015-01-01
# 2             3         2  five_cheese_l         1 2015-01-01
# 3             4         2    ital_supr_l         1 2015-01-01
# 4             5         2     mexicana_m         1 2015-01-01
# ...         ...       ...            ...       ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616     48617     21348  four_cheese_l         1 2015-12-31
# 48617     48618     21348   napolitana_s         1 2015-12-31
# 48618     48619     21349     mexicana_l         1 2015-12-31
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31
#
#                order_time  unit_price  total_price pizza_size pizza_category  \
# 0     2024-10-28 11:38:36       13.25        13.25          M        Classic
# ...

# %%
pizza_sales['pizza_name'].value_counts().sort_values().head()
# Out:
# pizza_name
# The Brie Carre Pizza         480
# The Mediterranean Pizza      923
# The Calabrese Pizza          927
# The Spinach Supreme Pizza    940
# The Soppressata Pizza        957
# Name: count, dtype: int64
